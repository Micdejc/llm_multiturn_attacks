# %%
# run_jailbroker

import importlib

# Import the module (not the class!)
import multiturn_jailbroker

# Reload the module (if needed)
importlib.reload(multiturn_jailbroker)

# Now import or use the class
from multiturn_jailbroker import MultiTurnJailbroker

if __name__ == "__main__":
    
    # Create an instance of the jailbroker
    jailbroker = MultiTurnJailbroker()

    # Variable for number of iterations in multi-turn attack
    nb_iter = 2

    # Variable for past tense reformulation in multi-turn attack
    is_past = True

    # Optional variables for the row range (human level) to select from the input file
    min_row = 2
    max_row = 4
    
    # We set the targeted LLM to close source LLM with index number 0 (chatGPT) from the list, Llama 2 is chosen by default. 
    # Refer to LLM lists in LLMAggregator Class
    #jailbroker.set_llm_index(False,0)

    # We set the temperature index to 2 (0.9) from the list. Index of 0 (value: 0.1) is chosen by default. 
    # Refer to TEMPS lists in LLMAggregator Class
    #jailbroker.set_temperature_index(2)
    
    #jailbroker.launch_single_turn_attack(is_past, min_row, max_row)
    jailbroker.launch_multiple_turn_attack(nb_iter, is_past, min_row, max_row)
# Out:
# Temperature updated to: 0.9
# LLM responses written to tests/llama-2-7b-chat/llama-2-7b-chat_attack_N_2_past.csv.
